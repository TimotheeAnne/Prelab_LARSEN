# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

# %%
data = scipy.io.loadmat("/home/tanne-local/Documents/handful-of-trials/scripts/log/2019-09-04--16:56:18/logs.mat")

# %%
obs = data['observations'][0]
rew = np.array(data['returns'][0])
acs = np.array(data['actions'][0])

# %%
velx = []
for i in range(len(obs)):
    velx.append(np.sum(obs[i][:,13]))

# %%
plt.plot(rew)

# %%
plt.plot(velx)

# %%
np.argmin(rew)
# Out:
# 37
